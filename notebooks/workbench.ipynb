# %%
import pandas as pd

df1 = pd.read_csv('../data/raw/oil_test.csv')
df2 = pd.read_csv('../data/raw/train_oil.csv')
df = pd.concat([df1, df2], ignore_index=True)

# %%
df
# Out:
#             Field name                  Reservoir unit           Country  \
# 0         ABU GHARADIG                        BAHARIYA             EGYPT
# 1     ABU MADI-EL QARA            ABU MADI (LEVEL III)             EGYPT
# 2           ALIBEKMOLA                            KT I        KAZAKHSTAN
# 3          ALWYN NORTH              BRENT (BRENT EAST)                UK
# 4           ANKLESHWAR        ANKLESHWAR (HAZAD-ARDOL)             INDIA
# ..                 ...                             ...               ...
# 437              HIDES                     IMBURU-TORO  PAPUA NEW GUINEA
# 438        DRAKE POINT      DRAKE POINT-INTREPID INLET            CANADA
# 439  ALTAMONT-BLUEBELL  GREEN RIVER AND COLTON/WASATCH               USA
# 440         BELL CREEK                           MUDDY               USA
# 441          WELL DRAW         MESAVERDE (TEAPOT SAND)               USA
#
#                   Region          Basin name  \
# ...
